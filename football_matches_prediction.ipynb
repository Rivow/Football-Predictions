# %%
import pandas as pd

# %%
data = pd.read_csv('matches.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1559 non-null   int64
#  1   date          1549 non-null   object
#  2   time          1549 non-null   object
#  3   comp          1559 non-null   object
#  4   round         1559 non-null   object
#  5   day           1549 non-null   object
#  6   venue         1559 non-null   object
#  7   result        1558 non-null   object
#  8   gf            1558 non-null   object
#  9   ga            1558 non-null   object
#  10  opponent      1559 non-null   object
#  11  poss          423 non-null    float64
#  12  attendance    1078 non-null   float64
#  13  captain       1246 non-null   object
#  14  formation     1122 non-null   object
#  15  referee       1510 non-null   object
#  16  match report  1559 non-null   object
#  17  notes         62 non-null     object
# ...

# %%
# Cleaning the names of the opponets
data['opponent'] = data['opponent'].str.split(' ').str[1:]
data['opponent'] = data['opponent'].str.join(' ')

# %%
data.drop(['match report', 'notes'], axis=1)
# Out:
#       Unnamed: 0        date   time            comp               round  day  \
# 0              0  2020-10-08  21:30             WCQ  WCQ — CONMEBOL (M)  Thu
# 1              1  2020-10-13  16:00             WCQ  WCQ — CONMEBOL (M)  Tue
# 2              2  2020-11-12  16:00             WCQ  WCQ — CONMEBOL (M)  Thu
# 3              3  2020-11-17  16:00             WCQ  WCQ — CONMEBOL (M)  Tue
# 4              4  2021-06-04  21:30             WCQ  WCQ — CONMEBOL (M)  Fri
# ...          ...         ...    ...             ...                 ...  ...
# 1554          25  2014-09-05  21:00  Friendlies (M)      Friendlies (M)  Fri
# 1555          26  2014-10-10  19:00  Friendlies (M)      Friendlies (M)  Fri
# 1556          27  2014-10-14  21:15  Friendlies (M)      Friendlies (M)  Tue
# 1557          28  2014-11-14  19:45  Friendlies (M)      Friendlies (M)  Fri
# 1558          29  2014-11-18  18:00  Friendlies (M)      Friendlies (M)  Tue
#
# ...

# %%
data_2022_2018 = data[(data['season'] == 2022) | (data['season'] == 2018)]

# %%
data_2022_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1328 entries, 0 to 1327
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1328 non-null   int64
#  1   date          1328 non-null   object
#  2   time          1328 non-null   object
#  3   comp          1328 non-null   object
#  4   round         1328 non-null   object
#  5   day           1328 non-null   object
#  6   venue         1328 non-null   object
#  7   result        1327 non-null   object
#  8   gf            1327 non-null   object
#  9   ga            1327 non-null   object
#  10  opponent      1328 non-null   object
#  11  poss          372 non-null    float64
#  12  attendance    877 non-null    float64
#  13  captain       1109 non-null   object
#  14  formation     1064 non-null   object
#  15  referee       1325 non-null   object
#  16  match report  1328 non-null   object
#  17  notes         53 non-null     object
# ...
